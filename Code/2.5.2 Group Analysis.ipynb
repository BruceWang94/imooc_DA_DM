# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/HR.csv')

## remove outlier
df = df.dropna(axis=0, how='any')
df = df[df['last_evaluation']<=1][df['salary']!='nme'][df['department']!='sale']
# Out:
# /Users/shiyuwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %% [markdown]
# The data can be shown clearly through the bar chart.

# %%
sns.barplot(x='salary', y = 'left', hue='department', data=df)
plt.show()

# %% [markdown]
# Let's check the continuous value, `satisfaction_level`.
#
# Here, **the code is time-consuming**.

# %%
sl_s = df['satisfaction_level']

# %%
sns.barplot(list(range(len(sl_s))), sl_s.sort_values())
